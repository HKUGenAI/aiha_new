# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.read_pickle("results/75YearsofEngineering_bbs.pkl")
df.head(10)
# Out:
#                          id  page  \
# 0  75YearsofEngineering_0_0     0
# 1  75YearsofEngineering_0_1     0
# 2  75YearsofEngineering_0_2     0
# 3  75YearsofEngineering_0_3     0
# 4  75YearsofEngineering_1_0     1
# 5  75YearsofEngineering_2_0     2
# 6  75YearsofEngineering_2_1     2
# 7  75YearsofEngineering_2_2     2
# 8  75YearsofEngineering_2_3     2
# 9  75YearsofEngineering_2_4     2
#
#                                                 xyxy  \
# 0  [[24.594837188720703, 190.00843811035156, 547....
# 1  [[245.9947509765625, 20.625307083129883, 324.8...
# 2  [[77.5875244140625, 125.02650451660156, 501.71...
# 3  [[77.5875244140625, 125.02650451660156, 501.71...
# 4  [[188.08712768554688, 209.71755981445312, 412....
# 5  [[164.08480834960938, 432.4455871582031, 428.6...
# 6  [[248.7919921875, 519.5856323242188, 343.33770...
# 7  [[179.55274963378906, 677.4924926757812, 411.2...
# 8  [[106.06077575683594, 212.73660278320312, 486....
# 9  [[252.90267944335938, 97.31399536132812, 342.4...
#
#                                          image_array  type    type_str  \
# 0  [[[180, 133, 111], [180, 133, 111], [182, 135,...     3      figure
# 1  [[[178, 129, 111], [177, 127, 109], [178, 128,...     2     abandon
# 2  [[[180, 130, 112], [181, 130, 113], [179, 129,...     0       title
# 3  [[[180, 130, 112], [181, 130, 113], [179, 129,...     1  plain text
# 4  [[[255, 255, 255], [255, 255, 255], [255, 255,...     3      figure
# 5  [[[255, 255, 255], [255, 255, 255], [255, 255,...     0       title
# 6  [[[255, 255, 255], [255, 255, 255], [255, 255,...     3      figure
# 7  [[[255, 255, 255], [255, 255, 255], [255, 255,...     1  plain text
# 8  [[[255, 255, 255], [255, 255, 255], [255, 255,...     0       title
# 9  [[[255, 255, 255], [255, 255, 255], [255, 255,...     2     abandon
#
#    type_conf
# 0   0.828285
# 1   0.756994
# 2   0.474311
# 3   0.294476
# 4   0.907374
# 5   0.771073
# 6   0.718801
# 7   0.714562
# 8   0.545822
# 9   0.490252

# %%
for i in range(10):
    image = df.iloc[i]["image_array"]
    print(df.iloc[i]["type_str"])
    plt.imshow(image, interpolation='nearest')
    plt.axis("off")
    plt.show()
# Out:
# figure
# abandon
# title
# plain text
# figure
# title
# figure
# plain text
# title
# abandon
